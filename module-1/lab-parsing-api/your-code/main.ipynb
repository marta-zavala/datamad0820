# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=84&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   TO121J05E-K11  HERITAGE ZIP THROUGH HOODIE - veste en sweat z...
# 1   CL111B0CM-Q11                    KAYLIN CARA - Escarpins - black
# 2   AD115O0DY-A12  STAN SMITH NEON HEEL SHOES - Baskets basses - ...
# 3   LE421A00G-K12           MARION STRAIGHT - Jean droit - night sky
# 4   LE221N07C-K14  725 HIGH RISE BOOTCUT - Jean bootcut - dark-bl...
# ..            ...                                                ...
# 79  AN621D0TC-P11                             T-shirt imprimé - teal
# 80  NM321G014-K11       NMDEBRA  - Veste en jean - medium blue denim
# 81  B2411A04V-Q11                       Baskets basses - black/white
# 82  LE221D03U-Q11              THE PERFECT - T-shirt imprimé - black
# 83  TO121D0DM-Q11       HERITAGE SHORT SLEEVE - Polo - masters black
#
#                                                 sizes  \
# 0                              [XS, S, M, L, XL, XXL]
# 1                            [35.5, 36, 37, 41.5, 42]
# 2   [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# 3   [26x31, 26x33, 27x31, 27x33, 28x31, 28x33, 28x...
# 4   [25x32, 26x30, 27x30, 27x32, 27x34, 28x30, 28x...
# ..                                                ...
# 79                                  [XS, S, M, L, XL]
# 80                               [36, 38, 40, 42, 44]
# 81                           [37, 38, 39, 40, 41, 42]
# 82                             [XXS, XS, S, M, L, XL]
# 83                   [XXS, XS, S, M, L, XL, XXL, 3XL]
#
#                                               url_key  \
# 0   tommy-hilfiger-heritage-zip-through-hoodie-ves...
# 1          clarks-kaylin-cara-escarpins-cl111b0cm-q11
# 2   adidas-originals-stan-smith-baskets-basses-ad1...
# 3        lee-marion-straight-jean-droit-le421a00g-k12
# 4   levisr-725-high-rise-bootcut-jean-bootcut-le22...
# ..                                                ...
# 79      anna-field-t-shirt-imprime-teal-an621d0tc-p11
# 80      noisy-may-nmdebra-veste-en-jean-nm321g014-k11
# 81  british-knights-baskets-basses-blackwhite-b241...
# 82   levisr-the-perfect-t-shirt-imprime-le221d03u-q11
# 83  tommy-hilfiger-heritage-short-sleeve-polo-to12...
#
#                                                 media        brand_name  \
# 0   [{'path': 'spp-media-p1/23df1d46ee603ed899c6dc...    Tommy Hilfiger
# 1   [{'path': 'spp-media-p1/029ad7a646eb3449be6c7c...            Clarks
# 2   [{'path': 'spp-media-p1/e5a1f1bb4a773572a034c7...  adidas Originals
# 3   [{'path': 'spp-media-p1/192dc262b2193e4eb9e58e...               Lee
# 4   [{'path': 'spp-media-p1/d5a8f4927c843002bb8162...           Levi's®
# ..                                                ...               ...
# 79  [{'path': 'spp-media-p1/b95cb66b8a233442b23dd0...        Anna Field
# 80  [{'path': 'spp-media-p1/d94393af35c03932b8ed53...         Noisy May
# 81  [{'path': 'spp-media-p1/cf008bd2da5131638a1246...   British Knights
# 82  [{'path': 'spp-media-p1/70ba0bd566b03138a0cd25...           Levi's®
# 83  [{'path': 'spp-media-p1/a1b719560c3c3bcf9ec53a...    Tommy Hilfiger
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': '-30%', 'tra...          shoe
# 2   [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# 3   [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 80  [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-50%', 'tra...          shoe
# 82  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': '-35%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []       119,95 €           95,95 €
# 1                 []        89,95 €           62,95 €
# 2                 []        99,95 €           74,95 €
# 3                 []        89,95 €           62,95 €
# 4                 []        99,95 €           79,95 €
# ..               ...            ...               ...
# 79                []        17,99 €           14,39 €
# 80                []        29,99 €           26,99 €
# 81                []        64,95 €           32,48 €
# 82                []        24,95 €           19,95 €
# 83                []        59,95 €           38,95 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                         True                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                     True
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only amount price.base_price outfits
# 0                                       False    NaN              NaN     NaN
# 1                                       False    NaN              NaN     NaN
# 2                                       False    NaN              NaN     NaN
# 3                                       False    NaN              NaN     NaN
# 4                                       False    NaN              NaN     NaN
# ..                                        ...    ...              ...     ...
# 79                                      False    NaN              NaN     NaN
# 80                                      False    NaN              NaN     NaN
# 81                                      False    NaN              NaN     NaN
# 82                                      False    NaN              NaN     NaN
# 83                                      False    NaN              NaN     NaN
#
# [84 rows x 20 columns]

# %%
total_pages=results['pagination']['page_count']

# %%
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=popularity'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages}", end='\r')

df.head()
# Out:
# getting page 867 of 892
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/Cellar/python/3.7.8/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _get_chunk_left(self)
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#
# /usr/local/Cellar/python/3.7.8/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     520         try:
# --> 521             return int(line, 16)
#     522         except ValueError:
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# /usr/local/Cellar/python/3.7.8/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _readall_chunked(self)
#     570             while True:
# --> 571                 chunk_left = self._get_chunk_left()
#     572                 if chunk_left is None:
#
# /usr/local/Cellar/python/3.7.8/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _get_chunk_left(self)
#     555             except ValueError:
# --> 556                 raise IncompleteRead(b'')
#     557             if chunk_left == 0:
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# <ipython-input-5-7c0ce0dcfb7e> in <module>
#       4     url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=popularity'
#       5     response = urllib.request.urlopen(url)
# ----> 6     results = json.load(response)
#       7     flattened_data = json_normalize(results)
#       8     flattened_data1 = json_normalize(flattened_data.articles[0])
#
# /usr/local/Cellar/python/3.7.8/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/local/Cellar/python/3.7.8/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in read(self, amt)
#     462
#     463             if self.chunked:
# --> 464                 return self._readall_chunked()
#     465
#     466             if self.length is None:
#
# /usr/local/Cellar/python/3.7.8/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _readall_chunked(self)
#     576             return b''.join(value)
#     577         except IncompleteRead:
# --> 578             raise IncompleteRead(b''.join(value))
#     579
#     580     def _readinto_chunked(self, b):
#
# IncompleteRead: IncompleteRead(188452 bytes read)

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
print(df.brand_name.value_counts().index[0])
# Out:
# myMo

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).name[0]
# Out:
# 'd'

# %%
print(df['discount_amount'].sum())
# Out:
# 1716488.8599999999
