# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   NI126G00D-A11    TEE FUTURA ICON - T-shirt imprimé - white/black
# 1   TO124K04Y-Q11                    ESSENTIAL  - Sweatshirt - black
# 2   NI114D052-Q11                             Baskets basses - black
# 3   LE226K003-G11  BATWING SCREENPRINT HOODIE - Sweat à capuche -...
# 4   AD543A1H1-Q11  TERREX AX2R - Chaussures de marche - core blac...
# ..            ...                                                ...
# 79  TO124I028-K11         BOYS SOLID STRETCH - Chemise - sky captain
# 80  NA823B0TZ-C11    NKFPOLLY TWITULEO PANT  - Jean slim - dark grey
# 81  JOC43K01R-Q11          23 MUSCLE SHORT SET - Survêtement - black
# 82  F5713G03A-O12                             Sandales - light brown
# 83  NI114D0AC-Q11               AIR MAX 270 - Baskets basses - black
#
#                                                 sizes  \
# 0                         [8-9a, 10-11a, 12-13a, 14a]
# 1   [3a, 4a, 5a, 6a, 7a, 8a, 10a, 12a, 14a, 16a, 1...
# 2          [17, 18.5, 19.5, 21, 22, 23.5, 25, 26, 27]
# 3        [2a, 3a, 4a, 5a, 6a, 8a, 10a, 12a, 14a, 16a]
# 4   [28, 28.5, 29, 30, 30.5, 31, 31.5, 32, 33, 33....
# ..                                                ...
# 79  [3a, 4a, 5a, 6a, 6-9m, 7a, 8a, 9-12m, 10a, 12a...
# 80                           [6a, 11a, 12a, 13a, 14a]
# 81                                    , 18m, 24m]
# 82                               [32, 34, 35, 36, 37]
# 83  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33, 3...
#
#                                               url_key  \
# 0   nike-sportswear-tee-futura-icon-t-shirt-imprim...
# 1   tommy-hilfiger-essential-sweatshirt-black-to12...
# 2   nike-sportswear-force-1-baskets-basses-ni114d0...
# 3   levisr-batwing-screenprint-hoodie-sweatshirt-l...
# 4   adidas-performance-terrex-ax2r-chaussures-de-r...
# ..                                                ...
# 79  tommy-hilfiger-boys-solid-stretch-chemise-to12...
# 80  name-it-nkfpolly-twituleo-pant-jean-slim-dark-...
# 81  jordan-23-muscle-short-set-survetement-black-j...
# 82          friboo-sandales-light-brown-f5713g03a-o12
# 83  nike-sportswear-air-max-270-baskets-basses-bla...
#
#                                                 media          brand_name  \
# 0   [{'path': 'spp-media-p1/fe69f85f40923cf589480b...     Nike Sportswear
# 1   [{'path': 'spp-media-p1/0a07268b130d3d10a7347b...      Tommy Hilfiger
# 2   [{'path': 'spp-media-p1/7e345fb047be3bd9beacf0...     Nike Sportswear
# 3   [{'path': 'spp-media-p1/711e633be3fe3fb7b85793...             Levi's®
# 4   [{'path': 'spp-media-p1/6b794a1fa0d73bc1b922b5...  adidas Performance
# ..                                                ...                 ...
# 79  [{'path': 'spp-media-p1/80c3bb27a7c93664822274...      Tommy Hilfiger
# 80  [{'path': 'spp-media-p1/3b3b2df25c2f33dc867237...             Name it
# 81  [{'path': 'spp-media-p1/1b12f9f035c03543895f09...              Jordan
# 82  [{'path': 'spp-media-p1/4e51f44cd5e63870a844e1...              Friboo
# 83  [{'path': 'spp-media-p1/c3eb29d7626031caa5b164...     Nike Sportswear
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 2   [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe
# 3   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-30%', 'tra...          shoe
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': 'Jusqu’à -17...      clothing
# 80  [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-40%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-40%', 'tra...          shoe
# 83  [{'key': 'discountRate', 'value': 'Jusqu’à -10...          shoe
#
#    delivery_promises price.original price.promotional  \
# 0                 []        17,95 €           15,25 €
# 1                 []        49,95 €           42,65 €
# 2                 []        49,95 €           42,45 €
# 3                 []        44,95 €           35,95 €
# 4                 []        49,95 €           34,95 €
# ..               ...            ...               ...
# 79                []        49,95 €           41,35 €
# 80                []        29,99 €           25,49 €
# 81                []        29,95 €           17,95 €
# 82                []        27,95 €           16,85 €
# 83                []        89,95 €           80,95 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                         True                                False
# 2                        False                                False
# 3                         True                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                        True                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                        True                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                     True
# 2                                    False
# 3                                     True
# 4                                    False
# ..                                     ...
# 79                                    True
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                    True
#
#     price.has_discount_on_selected_sizes_only amount
# 0                                       False    NaN
# 1                                       False    NaN
# 2                                       False    NaN
# 3                                       False    NaN
# 4                                       False    NaN
# ..                                        ...    ...
# 79                                      False    NaN
# 80                                      False    NaN
# 81                                      False    NaN
# 82                                      False    NaN
# 83                                      False    NaN
#
# [84 rows x 18 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages}", end='\r')

df
# Out:
# getting page 213 of 214
#                                                             name  \
# sku
# AD116D008-A11          STAN SMITH - Baskets basses - white/green
# LE226G007-C11  BATWING - T-shirt à manches longues - grey hea...
# AD116D07G-A11  STAN SMITH CF I - Chaussures premiers pas - wh...
# NI114D0CS-A11            COURT BOROUGH  - Baskets basses - white
# AD116D0MP-A11  STAN SMITH - Baskets basses - footwear white/c...
# ...                                                          ...
# MN684A002-K11       SET BOYS - Set de sous-vêtements - dark navy
# F0984A00C-G11  VOYAGER VEST BARNEY PRINTED BRIEF - Caraco - t...
# HY526G00L-T11                  SUB TEE - T-shirt imprimé - multi
# RI213I02J-O11               LUAN - Bottes de neige - curry/hazel
# PO224J03M-K11                      T-shirt imprimé - cruise navy
#
#                                                            sizes  \
# sku
# AD116D008-A11           [36, 38, 35 1/2, 36 2/3, 37 1/3, 38 2/3]
# LE226G007-C11                       [6a, 8a, 10a, 12a, 14a, 16a]
# AD116D07G-A11               [19, 20, 21, 22, 23, 24, 25, 26, 27]
# NI114D0CS-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# AD116D0MP-A11  [36, 38, 40, 35 1/2, 36 2/3, 37 1/3, 38 2/3, 3...
# ...                                                          ...
# MN684A002-K11                                               [2a]
# F0984A00C-G11                                             [6-7a]
# HY526G00L-T11                                              [13a]
# RI213I02J-O11                                               [28]
# PO224J03M-K11                                                [L]
#
#                                                          url_key  \
# sku
# AD116D008-A11  adidas-originals-stan-smith-baskets-basses-bla...
# LE226G007-C11  levisr-batwing-tee-t-shirt-a-manches-longues-l...
# AD116D07G-A11  adidas-originals-stan-smith-cf-i-baskets-basse...
# NI114D0CS-A11  nike-sportswear-court-borough-baskets-basses-n...
# AD116D0MP-A11  adidas-originals-stan-smith-baskets-basses-foo...
# ...                                                          ...
# MN684A002-K11  minymo-set-boys-set-de-sous-vetements-dark-nav...
# F0984A00C-G11  frugi-voyager-vest-barney-printed-brief-caraco...
# HY526G00L-T11   hype-sub-tee-t-shirt-imprime-multi-hy526g00l-t11
# RI213I02J-O11         ricosta-luan-bottes-de-neige-ri213i02j-o11
# PO224J03M-K11  polo-ralph-lauren-t-shirt-imprime-cruise-navy-...
#
#                                                            media  \
# sku
# AD116D008-A11  [{'path': 'spp-media-p1/6e77790477903cb2943858...
# LE226G007-C11  [{'path': 'spp-media-p1/dd9fded32dde3b17b0486c...
# AD116D07G-A11  [{'path': 'spp-media-p1/ce39b604a97b373bbe8e46...
# NI114D0CS-A11  [{'path': 'spp-media-p1/0b5fec9e420b37099ccfe6...
# AD116D0MP-A11  [{'path': 'spp-media-p1/e35946364032394ea54a0f...
# ...                                                          ...
# MN684A002-K11  [{'path': 'spp-media-p1/4254bc91e739395cb26d1a...
# F0984A00C-G11  [{'path': 'spp-media-p1/b5bbf78e19a432bf9d1928...
# HY526G00L-T11  [{'path': 'spp-media-p1/5420460ade793a348087ac...
# RI213I02J-O11  [{'path': 'spp-media-p1/654f023cf24231a9975f1b...
# PO224J03M-K11  [{'path': 'spp-media-p1/911e187ffaaf37ada7d61b...
#
#                       brand_name  is_premium family_articles  \
# sku
# AD116D008-A11   adidas Originals       False              []
# LE226G007-C11            Levi's®       False              []
# AD116D07G-A11   adidas Originals       False              []
# NI114D0CS-A11    Nike Sportswear       False              []
# AD116D0MP-A11   adidas Originals       False              []
# ...                          ...         ...             ...
# MN684A002-K11             Minymo       False              []
# F0984A00C-G11              Frugi       False              []
# HY526G00L-T11               Hype       False              []
# RI213I02J-O11            Ricosta       False              []
# PO224J03M-K11  Polo Ralph Lauren        True              []
#
#                                                            flags  \
# sku
# AD116D008-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# LE226G007-C11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# AD116D07G-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -25...
# NI114D0CS-A11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# AD116D0MP-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -20...
# ...                                                          ...
# MN684A002-K11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# F0984A00C-G11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# HY526G00L-T11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# RI213I02J-O11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# PO224J03M-K11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
#
#               product_group delivery_promises price.original  \
# sku
# AD116D008-A11          shoe                []        64,95 €
# LE226G007-C11      clothing                []        21,95 €
# AD116D07G-A11          shoe                []        49,95 €
# NI114D0CS-A11          shoe                []        34,95 €
# AD116D0MP-A11          shoe                []        64,95 €
# ...                     ...               ...            ...
# MN684A002-K11     underwear                []        18,95 €
# F0984A00C-G11     underwear                []        17,95 €
# HY526G00L-T11      clothing                []        17,95 €
# RI213I02J-O11          shoe                []        79,95 €
# PO224J03M-K11      clothing                []        33,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# AD116D008-A11           45,45 €                        True
# LE226G007-C11           16,45 €                        True
# AD116D07G-A11           37,45 €                        True
# NI114D0CS-A11           27,95 €                       False
# AD116D0MP-A11           51,95 €                        True
# ...                         ...                         ...
# MN684A002-K11           18,95 €                       False
# F0984A00C-G11           17,95 €                       False
# HY526G00L-T11           17,95 €                       False
# RI213I02J-O11           79,95 €                       False
# PO224J03M-K11           33,95 €                       False
#
#                price.has_different_original_prices  \
# sku
# AD116D008-A11                                False
# LE226G007-C11                                False
# AD116D07G-A11                                False
# NI114D0CS-A11                                False
# AD116D0MP-A11                                False
# ...                                            ...
# MN684A002-K11                                False
# F0984A00C-G11                                False
# HY526G00L-T11                                False
# RI213I02J-O11                                False
# PO224J03M-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# AD116D008-A11                                    True
# LE226G007-C11                                    True
# AD116D07G-A11                                    True
# NI114D0CS-A11                                   False
# AD116D0MP-A11                                    True
# ...                                               ...
# MN684A002-K11                                   False
# F0984A00C-G11                                   False
# HY526G00L-T11                                   False
# RI213I02J-O11                                   False
# PO224J03M-K11                                   False
#
#                price.has_discount_on_selected_sizes_only amount condition  \
# sku
# AD116D008-A11                                      False    NaN       NaN
# LE226G007-C11                                      False    NaN       NaN
# AD116D07G-A11                                      False    NaN       NaN
# NI114D0CS-A11                                      False    NaN       NaN
# AD116D0MP-A11                                      False    NaN       NaN
# ...                                                  ...    ...       ...
# MN684A002-K11                                      False    NaN       NaN
# F0984A00C-G11                                      False    NaN       NaN
# HY526G00L-T11                                      False    NaN       NaN
# RI213I02J-O11                                      False    NaN       NaN
# PO224J03M-K11                                      False    NaN       NaN
#
#               condition_key
# sku
# AD116D008-A11           NaN
# LE226G007-C11           NaN
# AD116D07G-A11           NaN
# NI114D0CS-A11           NaN
# AD116D0MP-A11           NaN
# ...                     ...
# MN684A002-K11           NaN
# F0984A00C-G11           NaN
# HY526G00L-T11           NaN
# RI213I02J-O11           NaN
# PO224J03M-K11           NaN
#
# [17948 rows x 19 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Boboli'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Naturino'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# brand_name
# Angel & Rocket             0.0
# Belstaff                   0.0
# Bergstein                  0.0
# Bikkembergs Kids           0.0
# Bogs                       0.0
# Bomboogie                  0.0
# Craft                      0.0
# Fabrizio                   0.0
# Finger in the nose         0.0
# GRO                        0.0
# Hip                        0.0
# Jack & Jones               0.0
# KG by Kurt Geiger          0.0
# Kempa                      0.0
# MP Denmark                 0.0
# Modern Native              0.0
# Nike Golf                  0.0
# Noa Noa                    0.0
# ODLO                       0.0
# Outerstuff                 0.0
# Outfit Kids                0.0
# Pinocchio                  0.0
# Play Up                    0.0
# Reebok Classic             0.0
# Regatta                    0.0
# Save the duck              0.0
# Schott                     0.0
# Scotch R'Belle             0.0
# Sisley                     0.0
# Sonia Rykiel               0.0
# Steiff Shoes               0.0
# THE ANIMALS OBSERVATORY    0.0
# THE WHITE BRAND            0.0
# TOMS                       0.0
# Uhlsport                   0.0
# Umbro                      0.0
# Unauthorized               0.0
# Victoria Shoes             0.0
# Vilebrequin                0.0
# XTI                        0.0
# fullstop.                  0.0
# mtng                       0.0
# pick & PACK                0.0
# shoeb76                    0.0
# Name: discount_amount, dtype: float64
